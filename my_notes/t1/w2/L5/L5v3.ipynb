# %% [markdown]
# ![](https://github.com/book-g/only_image/blob/main/L5v3%20+%20Gravity%20at%20the%20surface%20of%20the%20Earth%20+%20The%20value%20of%20g..jpeg?raw=true)

# %% [markdown]
# Here is the **step-by-step algorithm** to compute **gravitational acceleration (g)** at the **surface of the Earth** based on the text and the attached image.
#
# ---
#
# ### 🔑 **Key Equation**
#
# The gravitational force between two masses:
#
# $$
# \vec{F}_{12} = -G \frac{m_1 m_2}{r_{12}^2} \hat{r}_{12}
# $$
#
# When on Earth’s surface:
#
# $$
# F = mg \Rightarrow g = \frac{GM_E}{R_E^2}
# $$
#
# ---
#
# ### ✅ **Algorithm: Step-by-Step Calculation of $g_{\text{Earth}}$**
#
# #### **Step 0: Definitions (Initialize constants)**
#
# * $G = 6.674 \times 10^{-11} \, \mathrm{N \cdot m^2/kg^2}$ — Universal gravitational constant
# * $M_E = 5.972 \times 10^{24} \, \mathrm{kg}$ — Mass of the Earth
# * $R_E = 6.371 \times 10^6 \, \mathrm{m}$ — Radius of the Earth
#
# ---
#
# #### **Step 1: Write Newton's Law of Universal Gravitation**
#
# $$
# F = G \frac{M_E m}{R_E^2}
# $$
#
# ---
#
# #### **Step 2: Equate gravitational force to weight**
#
# $$
# mg = G \frac{M_E m}{R_E^2}
# $$
#
# ---
#
# #### **Step 3: Cancel test mass $m$ from both sides**
#
# $$
# g = G \frac{M_E}{R_E^2}
# $$
#
# ---
#
# #### **Step 4: Plug in values**
#
# $$
# g = \frac{6.674 \times 10^{-11} \times 5.972 \times 10^{24}}{(6.371 \times 10^6)^2}
# $$
#
# ---
#
# #### **Step 5: Perform numerical calculation**
#
# $$
# g \approx \frac{3.986 \times 10^{14}}{4.058 \times 10^{13}} \approx 9.81 \, \mathrm{m/s^2}
# $$
#
# ---
#
# ### 🧪 Example in Code (Proof)
#
# ```python
# # Gravitational acceleration at Earth's surface
# G = 6.674 * 10**-11         # N·m²/kg²
# M_E = 5.972 * 10**24        # kg
# R_E = 6.371 * 10**6         # m
#
# g = G * M_E / R_E**2
# print(f"Gravitational acceleration (g): {g:.2f} m/s²")
# ```
#
# ---
#
# ### 📊 Table: g on Different Planets
#
# | Planet  | Mass (kg)              | Radius (m)          | g (m/s²) |
# | ------- | ---------------------- | ------------------- | -------- |
# | Earth   | $5.972 \times 10^{24}$ | $6.371 \times 10^6$ | 9.81     |
# | Moon    | $7.35 \times 10^{22}$  | $1.74 \times 10^6$  | 1.62     |
# | Mars    | $6.39 \times 10^{23}$  | $3.39 \times 10^6$  | 3.71     |
# | Jupiter | $1.90 \times 10^{27}$  | $6.99 \times 10^7$  | 24.79    |
#
# ---
#
# ### 🌍 Applications
#
# * Satellite launch calculations
# * Space travel and planetary exploration
# * Physics simulations and mechanics
# * Weight measurements on different planets
#
# ---
#
# ### 📈 Graph (g vs. Distance from Earth Center)
#
# * $g$ decreases as distance from Earth's center increases (inverse-square relation).
#
# ---
#
# ### ✅ Summary
#
# | Key Concept             | Value / Formula                      |
# | ----------------------- | ------------------------------------ |
# | Gravitational Constant  | $G = 6.674 \times 10^{-11}$ N·m²/kg² |
# | Surface gravity (Earth) | $g = 9.81 \, \mathrm{m/s^2}$         |
# | Formula Used            | $g = \frac{GM_E}{R_E^2}$             |
# | Dependence              | Mass and radius of planet            |
#
# ---
#
# If you'd like a version of this in a simulator or diagrammatic notebook (e.g., Desmos, Geogebra, or a Jupyter notebook), I can generate that too. Would you like that?

# %%
# Gravitational acceleration at Earth's surface
G = 6.674 * 10**-11         # N·m²/kg²
M_E = 5.972 * 10**24        # kg
R_E = 6.371 * 10**6         # m

g = G * M_E / R_E**2
print(f"Gravitational acceleration (g): {g:.2f} m/s²")
# Out:
# Gravitational acceleration (g): 9.82 m/s²
